# %% [markdown]
# <a href="https://colab.research.google.com/github/Dani-ID/pemrograman-komputer-5018251077/blob/main/Week02/W02_Engineering_Calculator_5018251077.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# Nama : Dani Arkanata
# NRP : 5018251077
# Kelas : A

# %%
v_kmh = float(input("Kecepatan [km/h]: "))
v_ms = v_kmh / 3.6
print(f"Kecepatan = {v_ms} m/s")
# Out:
# Kecepatan [km/h]: 9
# Kecepatan = 2.5 m/s

# %%
p_kw = float(input("daya [kW]: "))
p_w = p_kw / 1000
print(f"daya = {p_w} W")
# Out:
# daya [kW]: 79
# daya = 0.079 W

# %%
tegangan = float(input("Tegangan: (V)"))
arus = float(input("Arus: (A)"))
waktu = float(input("Waktu: (Jam)"))
daya = arus * tegangan
energi = daya * waktu

print(f"daya = {daya}")
print(f"energi = {energi}")
# Out:
# Tegangan: (V)90
# Arus: (A)8
# Waktu: (Jam)7
# daya = 720.0
# energi = 5040.0

# %%
tegangan = float(input("Tegangan: (V)"))
arus = float(input("Arus: (A)"))
waktu = float(input("Waktu: (Jam)"))
daya = arus * tegangan
energi = daya * waktu

power_limit = 200
voltage_limit = 24

is_high_power = daya > power_limit
is_high_voltage = tegangan > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
print("")

print(f"daya = {daya}")
print(f"energi = {energi}")
# Out:
# Tegangan: (V)89
# Arus: (A)9
# Waktu: (Jam)76
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True
#
# daya = 801.0
# energi = 60876.0

# %%
tegangan = float(input("Tegangan: (V)"))
arus = float(input("Arus: (A)"))
waktu = float(input("Waktu: (Jam)"))
daya = arus * tegangan
energi = daya * waktu

print(f"daya = {daya}")
print(f"energi = {energi}")
# Out:
# Tegangan: (V)12
# Arus: (A)5.0
# Waktu: (Jam)2.0
# daya = 60.0
# energi = 120.0

# %%
tegangan = float(input("Tegangan: (V)"))
arus = float(input("Arus: (A)"))
waktu = float(input("Waktu: (Jam)"))
daya = arus * tegangan
energi = daya * waktu

print(f"daya = {daya}")
print(f"energi = {energi}")
# Out:
# Tegangan: (V)24
# Arus: (A)8.5
# Waktu: (Jam)3.0
# daya = 204.0
# energi = 612.0

# %%
tegangan = float(input("Tegangan: (V)"))
arus = float(input("Arus: (A)"))
waktu = float(input("Waktu: (Jam)"))
daya = arus * tegangan
energi = daya * waktu

print(f"daya = {daya}")
print(f"energi = {energi}")
# Out:
# Tegangan: (V)48
# Arus: (A)10.0
# Waktu: (Jam)1.5
# daya = 480.0
# energi = 720.0

# %% [markdown]
# Jawaban short reflection
# 1. int adalah tipe data angka yang hanya mendukung bilangan bulat saja sedangkan float untuk angka dan mendukung bilangan desimal.
# 2. hasil input perlu dikonversi ke float agar tipe datanya berubah dari str ke float sehingga bisa dilakukan operasi matematika
# 3. operator = untuk menetapkan atau memasukkan sebuah nilai ke variabel sedangkan == untuk membandingkan dua data dan memeriksa apakah keduanya memiliki nilai yang sama.
# 4.
# and : semua kondisi harus benar agar menghasillkan true
# or : hanya butuh salah satu kondisi yang benar agar menghasilkan true.
# 5. kesalahan saya adalah ketika lupa menambahkan float pada input sehingga operasi matematikanya error. cara saya mengatasinya adalah dengan membaca penyebab error lalu mencari solusi melalui materi ppt. Setelah saya memahami dan melakukan seperti di materi, error terselesaikan./
